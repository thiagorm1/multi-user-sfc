# %% [markdown]
# # Objetivos
#
# - [Gráfico 1](#gr1): taxa de sucesso na realocação. Usuários afetados que foram realocados devidamente dividido pelo total de usuários afetados
#
#
# - [Gráfico 2](#gr2): Taxa de utilização de Espaço da Rede: que é quão bem a abordagem está aproveitando o espaço de armazenamento disponível após uma falha na rede. Uma taxa alta indica uma boa utilização dos recursos
#
# - [Gráfico 3](#gr3): -Taxa de perda de benefícios: O quão o usuário foi prejudicado nessa realocação em comparação com a alocação antiga dele
#
#
# - [Gráfico 4](#gr4): - tempo de realocação

# %% [markdown]
# ### Configuração inicial
#
# Importando bibliotecas necessárias

# %%
import glob
import os
import pandas as pd

# import seaborn as sns
# import plotly.graph_objects as go
# import plotly.io as pio
# import plotly.express as px


import warnings

warnings.filterwarnings("ignore")
warnings.simplefilter("ignore")

# %% [markdown]
# ### Carregamento dos dados

# %%
results_res_directories = glob.glob(
    "../../results/results_resilient*/*"
)  # Caso mude a estrutura dos diretórios, esse caminho deve ser alterado
results_res_directories
# Out:
# ['../../results\\results_resilient\\ga_s_50_p_4_a_0.95_c_3',
#  '../../results\\results_resilient\\ga_s_50_p_4_a_0.97_c_3',
#  '../../results\\results_resilient\\ga_s_50_p_4_a_0.99_c_3',
#  '../../results\\results_resilient\\ga_s_50_p_4_a_1.0_c_0',
#  '../../results\\results_resilient\\g_s_50_p_4_a_0.95_c_3',
#  '../../results\\results_resilient\\g_s_50_p_4_a_0.97_c_3',
#  '../../results\\results_resilient\\g_s_50_p_4_a_0.99_c_3',
#  '../../results\\results_resilient\\g_s_50_p_4_a_1.0_c_0',
#  '../../results\\results_resilient\\msf_s_50_p_4_a_0.95_c_3',
#  '../../results\\results_resilient\\msf_s_50_p_4_a_0.97_c_3',
#  '../../results\\results_resilient\\msf_s_50_p_4_a_0.99_c_3',
#  '../../results\\results_resilient\\msf_s_50_p_4_a_1.0_c_0',
#  '../../results\\results_resilient\\musfico_s_50_p_4_a_0.95_c_3',
#  '../../results\\results_resilient\\musfico_s_50_p_4_a_0.97_c_3',
#  '../../results\\results_resilient\\musfico_s_50_p_4_a_0.99_c_3',
#  '../../results\\results_resilient\\musfico_s_50_p_4_a_1.0_c_0']

# %%
for alg_dir in results_res_directories:
    simulacoes_okays = 0
    simu_exec_name = alg_dir.split("/")[-1].split("_")
    print(simu_exec_name)
    alg_name = simu_exec_name[0]
    print(alg_name)
# Out:
# ['results\\results', 'resilient\\ga', 's', '50', 'p', '4', 'a', '0.95', 'c', '3']
# results\results
# ['results\\results', 'resilient\\ga', 's', '50', 'p', '4', 'a', '0.97', 'c', '3']
# results\results
# ['results\\results', 'resilient\\ga', 's', '50', 'p', '4', 'a', '0.99', 'c', '3']
# results\results
# ['results\\results', 'resilient\\ga', 's', '50', 'p', '4', 'a', '1.0', 'c', '0']
# results\results
# ['results\\results', 'resilient\\g', 's', '50', 'p', '4', 'a', '0.95', 'c', '3']
# results\results
# ['results\\results', 'resilient\\g', 's', '50', 'p', '4', 'a', '0.97', 'c', '3']
# results\results
# ['results\\results', 'resilient\\g', 's', '50', 'p', '4', 'a', '0.99', 'c', '3']
# results\results
# ['results\\results', 'resilient\\g', 's', '50', 'p', '4', 'a', '1.0', 'c', '0']
# results\results
# ['results\\results', 'resilient\\msf', 's', '50', 'p', '4', 'a', '0.95', 'c', '3']
# results\results
# ['results\\results', 'resilient\\msf', 's', '50', 'p', '4', 'a', '0.97', 'c', '3']
# results\results
# ['results\\results', 'resilient\\msf', 's', '50', 'p', '4', 'a', '0.99', 'c', '3']
# results\results
# ['results\\results', 'resilient\\msf', 's', '50', 'p', '4', 'a', '1.0', 'c', '0']
# results\results
# ['results\\results', 'resilient\\musfico', 's', '50', 'p', '4', 'a', '0.95', 'c', '3']
# results\results
# ['results\\results', 'resilient\\musfico', 's', '50', 'p', '4', 'a', '0.97', 'c', '3']
# results\results
# ['results\\results', 'resilient\\musfico', 's', '50', 'p', '4', 'a', '0.99', 'c', '3']
# results\results
# ['results\\results', 'resilient\\musfico', 's', '50', 'p', '4', 'a', '1.0', 'c', '0']
# results\results

# %%
aggregated_simulation_data = pd.DataFrame()
algos = {}


def collect_data_from_alg_directory(results_res_directories):
    data_nla = []
    log_simu = {}  # Essa variável serve apenas para verificar as simulações

    for alg_dir in results_res_directories:
        simu_exec_name = alg_dir.split("/")[-1].split("_")

        # if simu_exec_name [2] == 'backup':
        #     alg_name = 'goku_backup'
        # else:
        alg_name = simu_exec_name[1].split("\\")[1]  # simu_exec_name[3].split(f'\\')[1]
        # reliability = simu_exec_name[-1]
        if alg_name == "g":
            alg_name = "Greedy"
        if alg_name == "ga":
            alg_name = "GA"
        if alg_name == "msf":
            alg_name = "MSF"
        if alg_name == "goku":
            alg_name = "OSCIM"
        if alg_name == "vegeta":
            alg_name = "Resilient-OSCIM"
        if alg_name == "musfico":
            alg_name = "MuSFiCO"
        if alg_name == "old":
            alg_name = "All Backup"
        files = os.listdir(alg_dir)
        # print(f"Simulação: {alg_name}, {reliability}")
        # print("Quantidade de csv: ", len(files))

        if alg_name not in log_simu:
            log_simu[alg_name] = {"files": len(files), "simulacoes_sucesso": 0, "Nulos": 0}
        else:
            log_simu[alg_name]["files"] += len(files)

        for file in files:
            data_path = os.path.join(alg_dir, file)
            try:
                simulation_df = pd.read_csv(data_path)
            except Exception as e:
                print(f"Erro ao ler o arquivo {file}: {e}")
                continue

            if not simulation_df.empty:
                # Calculations
                mean_data_frame = pd.DataFrame()
                recover_success_rate = simulation_df["recover_success"].mean()
                backup_success_rate = simulation_df["backup_success"].mean()
                latency_diff_mean = simulation_df["latency_diff"].dropna().mean()
                time_to_recover_mean = simulation_df["time_to_recover"].dropna().mean()

                # Cálculo do percentual de melhoria da latência
                improvement_percentage = ((5 - latency_diff_mean) / 10) * 100

                mean_data_frame["recover_success"] = [recover_success_rate]
                mean_data_frame["backup_success"] = [backup_success_rate]
                mean_data_frame["latency_diff"] = [latency_diff_mean]
                mean_data_frame["latency_improvement"] = [improvement_percentage]
                mean_data_frame["time_to_recover"] = [time_to_recover_mean]

                # Seleciona as métricas relevantes
                mean_data_frame["algorithm"] = alg_name
                mean_data_frame["simulation"] = log_simu[alg_name]["simulacoes_sucesso"]
                print(mean_data_frame)
                # print(mean_data_frame)
                data_nla.append(mean_data_frame)

                # Incrementa a contagem de simulações de sucesso e soma os valores nulos
                log_simu[alg_name]["simulacoes_sucesso"] += 1
                log_simu[alg_name]["Nulos"] += sum(mean_data_frame.isnull().sum())
    if data_nla:
        data_nla_f = pd.concat(data_nla)
    else:
        data_nla_f = pd.DataFrame()

    print("\nResumo das Simulações:")
    for alg, info in log_simu.items():
        print(f"Algoritmo: {alg}")
        print(f"  Quantidade de arquivos: {info['files']}")
        print(f"  Simulações de sucesso: {info['simulacoes_sucesso']}")
        print(f"  Dados nulos: {info['Nulos']}")
        print()

    return data_nla_f

# %%
aggregated_simulation_data = collect_data_from_alg_directory(results_res_directories)
# Out:
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0     -0.142857            51.428571
#
#    time_to_recover algorithm  simulation
# 0        15.653104        GA           0
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0      0.533333            44.666667
#
#    time_to_recover algorithm  simulation
# 0        18.344961        GA           1
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0         0.857143             0.0      0.055556            49.444444
#
#    time_to_recover algorithm  simulation
# 0        17.795003        GA           2
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0            0.875             0.0      0.142857            48.571429
#
#    time_to_recover algorithm  simulation
# 0        22.161413        GA           3
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0         0.863636             0.0     -0.052632            50.526316
#
#    time_to_recover algorithm  simulation
# 0        29.219553        GA           4
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0         0.916667             0.0      0.409091            45.909091
#
#    time_to_recover algorithm  simulation
# 0        17.938236        GA           5
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0         0.894737             0.0      0.411765            45.882353
#
#    time_to_recover algorithm  simulation
# 0        18.469788        GA           6
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              0.8             0.0       0.40625              45.9375
#
#    time_to_recover algorithm  simulation
# 0         19.88751        GA           7
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0      0.470588            45.294118
#
#    time_to_recover algorithm  simulation
# 0        20.436024        GA           8
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              0.8             0.0         -0.15                 51.5
#
#    time_to_recover algorithm  simulation
# 0        22.098395        GA           9
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0      0.131579            48.684211
#
#    time_to_recover algorithm  simulation
# 0        16.025722        GA          10
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0             0.76             0.0      0.736842            42.631579
#
#    time_to_recover algorithm  simulation
# 0        24.916495        GA          11
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0         0.869565             0.0         0.325                46.75
#
#    time_to_recover algorithm  simulation
# 0         12.00204        GA          12
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0         0.785714             0.0      0.454545            45.454545
#
#    time_to_recover algorithm  simulation
# 0        21.624647        GA          13
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0         0.826087             0.0      0.394737            46.052632
#
#    time_to_recover algorithm  simulation
# 0        16.546764        GA          14
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0         0.842105             0.0      -0.09375              50.9375
#
#    time_to_recover algorithm  simulation
# 0        21.575311        GA          15
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              0.7             0.0     -0.119048            51.190476
#
#    time_to_recover algorithm  simulation
# 0        21.074578        GA          16
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0         0.789474             0.0     -0.133333            51.333333
#
#    time_to_recover algorithm  simulation
# 0        21.089346        GA          17
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0         0.909091             0.0          -0.2                 52.0
#
#    time_to_recover algorithm  simulation
# 0         22.58355        GA          18
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0         0.894737             0.0      0.264706            47.352941
#
#    time_to_recover algorithm  simulation
# 0         23.93248        GA          19
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0         0.818182             0.0     -0.305556            53.055556
#
#    time_to_recover algorithm  simulation
# 0        20.630897        GA          20
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0             0.92             0.0     -0.086957            50.869565
#
#    time_to_recover algorithm  simulation
# 0        21.505502        GA          21
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0            0.875             0.0      0.261905            47.380952
#
#    time_to_recover algorithm  simulation
# 0        19.252706        GA          22
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              0.9             0.0     -0.333333            53.333333
#
#    time_to_recover algorithm  simulation
# 0        18.207593        GA          23
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0             0.95             0.0      0.526316            44.736842
#
#    time_to_recover algorithm  simulation
# 0        22.637159        GA          24
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0         0.863636             0.0      0.342105            46.578947
#
#    time_to_recover algorithm  simulation
# 0        22.313497        GA          25
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0         0.894737             0.0      0.529412            44.705882
#
#    time_to_recover algorithm  simulation
# 0        19.001767        GA          26
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0         0.809524             0.0      0.382353            46.176471
#
#    time_to_recover algorithm  simulation
# 0        20.268821        GA          27
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0         0.896552             0.0      0.365385            46.346154
#
#    time_to_recover algorithm  simulation
# 0        21.249587        GA          28
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0         0.833333             0.0          0.22                 47.8
#
#    time_to_recover algorithm  simulation
# 0        19.307414        GA          29
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0         0.631579             0.0         0.625                43.75
#
#    time_to_recover algorithm  simulation
# 0        20.055341    Greedy           0
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0      0.583333            44.166667
#
#    time_to_recover algorithm  simulation
# 0        18.597513    Greedy           1
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0         0.933333             0.0          0.75                 42.5
#
#    time_to_recover algorithm  simulation
# 0        24.025187    Greedy           2
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0         0.866667             0.0      0.480769            45.192308
#
#    time_to_recover algorithm  simulation
# 0        18.533623    Greedy           3
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0          0.92                 40.8
#
#    time_to_recover algorithm  simulation
# 0        20.822788    Greedy           4
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0      0.190476            48.095238
#
#    time_to_recover algorithm  simulation
# 0        24.156023    Greedy           5
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0             0.64             0.0       0.96875              40.3125
#
#    time_to_recover algorithm  simulation
# 0        19.000968    Greedy           6
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0      0.541667            44.583333
#
#    time_to_recover algorithm  simulation
# 0        20.484414    Greedy           7
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0      0.765625             42.34375
#
#    time_to_recover algorithm  simulation
# 0        25.321108    Greedy           8
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0      0.814815            41.851852
#
#    time_to_recover algorithm  simulation
# 0        18.010574    Greedy           9
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0        0.8125               41.875
#
#    time_to_recover algorithm  simulation
# 0        19.285133    Greedy          10
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0         0.794872             0.0      0.935484            40.645161
#
#    time_to_recover algorithm  simulation
# 0        24.697913    Greedy          11
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0       0.72973            42.702703
#
#    time_to_recover algorithm  simulation
# 0        22.879189    Greedy          12
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0      0.537037             44.62963
#
#    time_to_recover algorithm  simulation
# 0        14.558628    Greedy          13
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0           0.5                 45.0
#
#    time_to_recover algorithm  simulation
# 0        19.222554    Greedy          14
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0         0.904762             0.0      0.789474            42.105263
#
#    time_to_recover algorithm  simulation
# 0        28.305517    Greedy          15
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0           0.5625             0.0      0.916667            40.833333
#
#    time_to_recover algorithm  simulation
# 0        19.838829    Greedy          16
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0         0.821429             0.0      0.826087             41.73913
#
#    time_to_recover algorithm  simulation
# 0        17.793463    Greedy          17
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0      0.869565            41.304348
#
#    time_to_recover algorithm  simulation
# 0         21.49738    Greedy          18
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0         0.833333             0.0          0.78                 42.2
#
#    time_to_recover algorithm  simulation
# 0        22.292038    Greedy          19
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0             0.75             0.0      0.583333            44.166667
#
#    time_to_recover algorithm  simulation
# 0         27.26691    Greedy          20
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0        1.0625               39.375
#
#    time_to_recover algorithm  simulation
# 0        15.596124    Greedy          21
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0      0.407407            45.925926
#
#    time_to_recover algorithm  simulation
# 0        30.360814    Greedy          22
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0        0.0625               49.375
#
#    time_to_recover algorithm  simulation
# 0         27.18817    Greedy          23
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0         0.904762             0.0      0.973684            40.263158
#
#    time_to_recover algorithm  simulation
# 0        18.996105    Greedy          24
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0         0.736842             0.0      0.964286            40.357143
#
#    time_to_recover algorithm  simulation
# 0        14.407124    Greedy          25
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0         0.828571             0.0      0.448276            45.517241
#
#    time_to_recover algorithm  simulation
# 0        23.783245    Greedy          26
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0         0.612903             0.0      0.684211            43.157895
#
#    time_to_recover algorithm  simulation
# 0        15.048208    Greedy          27
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0      0.851351            41.486486
#
#    time_to_recover algorithm  simulation
# 0        17.608342    Greedy          28
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0          0.84375             0.0       0.62963            43.703704
#
#    time_to_recover algorithm  simulation
# 0        23.490985    Greedy          29
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0        -0.625                56.25
#
#    time_to_recover algorithm  simulation
# 0        25.215368       MSF           0
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0     -1.386364            63.863636
#
#    time_to_recover algorithm  simulation
# 0         21.35887       MSF           1
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0      0.480769            45.192308
#
#    time_to_recover algorithm  simulation
# 0        21.157314       MSF           2
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0         0.952381             0.0        -0.975                59.75
#
#    time_to_recover algorithm  simulation
# 0        17.878719       MSF           3
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0         0.961538             0.0         -0.54                 55.4
#
#    time_to_recover algorithm  simulation
# 0        22.666361       MSF           4
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0           0.9375             0.0     -0.333333            53.333333
#
#    time_to_recover algorithm  simulation
# 0        19.979539       MSF           5
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0     -0.886364            58.863636
#
#    time_to_recover algorithm  simulation
# 0        24.115336       MSF           6
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0      0.189655            48.103448
#
#    time_to_recover algorithm  simulation
# 0        18.182312       MSF           7
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0     -0.137931             51.37931
#
#    time_to_recover algorithm  simulation
# 0        19.992798       MSF           8
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0         0.863636             0.0     -0.026316            50.263158
#
#    time_to_recover algorithm  simulation
# 0        24.561506       MSF           9
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0     -0.925926            59.259259
#
#    time_to_recover algorithm  simulation
# 0        20.955565       MSF          10
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0          -0.5                 55.0
#
#    time_to_recover algorithm  simulation
# 0        19.796926       MSF          11
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0      0.613636            43.863636
#
#    time_to_recover algorithm  simulation
# 0        23.109636       MSF          12
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0     -0.647059            56.470588
#
#    time_to_recover algorithm  simulation
# 0        21.087822       MSF          13
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0     -0.153846            51.538462
#
#    time_to_recover algorithm  simulation
# 0          21.5056       MSF          14
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0     -0.969697             59.69697
#
#    time_to_recover algorithm  simulation
# 0        19.223654       MSF          15
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0     -0.978261            59.782609
#
#    time_to_recover algorithm  simulation
# 0        18.455793       MSF          16
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0     -0.543478            55.434783
#
#    time_to_recover algorithm  simulation
# 0        19.287181       MSF          17
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0        -0.225                52.25
#
#    time_to_recover algorithm  simulation
# 0        22.398228       MSF          18
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0     -0.482759            54.827586
#
#    time_to_recover algorithm  simulation
# 0        21.345262       MSF          19
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0            0.875             0.0      -0.97619            59.761905
#
#    time_to_recover algorithm  simulation
# 0         20.57216       MSF          20
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0     -0.034483            50.344828
#
#    time_to_recover algorithm  simulation
# 0        23.429926       MSF          21
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0           0.0                 50.0
#
#    time_to_recover algorithm  simulation
# 0        22.628954       MSF          22
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0     -0.326087             53.26087
#
#    time_to_recover algorithm  simulation
# 0        23.430978       MSF          23
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0     -0.386364            53.863636
#
#    time_to_recover algorithm  simulation
# 0        17.778386       MSF          24
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0        -0.875                58.75
#
#    time_to_recover algorithm  simulation
# 0        23.110871       MSF          25
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0         0.916667             0.0      0.386364            46.136364
#
#    time_to_recover algorithm  simulation
# 0         18.56002       MSF          26
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0         0.958333             0.0     -0.652174            56.521739
#
#    time_to_recover algorithm  simulation
# 0        18.532888       MSF          27
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0     -1.660714            66.607143
#
#    time_to_recover algorithm  simulation
# 0         20.86881       MSF          28
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              1.0             0.0     -0.630435            56.304348
#
#    time_to_recover algorithm  simulation
# 0        24.635793       MSF          29
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              0.0             0.0           NaN                  NaN
#
#    time_to_recover algorithm  simulation
# 0              NaN   MuSFiCO           0
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              0.0             0.0           NaN                  NaN
#
#    time_to_recover algorithm  simulation
# 0              NaN   MuSFiCO           1
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              0.0             0.0           NaN                  NaN
#
#    time_to_recover algorithm  simulation
# 0              NaN   MuSFiCO           2
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              0.0             0.0           NaN                  NaN
#
#    time_to_recover algorithm  simulation
# 0              NaN   MuSFiCO           3
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              0.0             0.0           NaN                  NaN
#
#    time_to_recover algorithm  simulation
# 0              NaN   MuSFiCO           4
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              0.0             0.0           NaN                  NaN
#
#    time_to_recover algorithm  simulation
# 0              NaN   MuSFiCO           5
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              0.0             0.0           NaN                  NaN
#
#    time_to_recover algorithm  simulation
# 0              NaN   MuSFiCO           6
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              0.0             0.0           NaN                  NaN
#
#    time_to_recover algorithm  simulation
# 0              NaN   MuSFiCO           7
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              0.0             0.0           NaN                  NaN
#
#    time_to_recover algorithm  simulation
# 0              NaN   MuSFiCO           8
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              0.0             0.0           NaN                  NaN
#
#    time_to_recover algorithm  simulation
# 0              NaN   MuSFiCO           9
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              0.0             0.0           NaN                  NaN
#
#    time_to_recover algorithm  simulation
# 0              NaN   MuSFiCO          10
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              0.0             0.0           NaN                  NaN
#
#    time_to_recover algorithm  simulation
# 0              NaN   MuSFiCO          11
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              0.0             0.0           NaN                  NaN
#
#    time_to_recover algorithm  simulation
# 0              NaN   MuSFiCO          12
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              0.0             0.0           NaN                  NaN
#
#    time_to_recover algorithm  simulation
# 0              NaN   MuSFiCO          13
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              0.0             0.0           NaN                  NaN
#
#    time_to_recover algorithm  simulation
# 0              NaN   MuSFiCO          14
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              0.0             0.0           NaN                  NaN
#
#    time_to_recover algorithm  simulation
# 0              NaN   MuSFiCO          15
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              0.0             0.0           NaN                  NaN
#
#    time_to_recover algorithm  simulation
# 0              NaN   MuSFiCO          16
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              0.0             0.0           NaN                  NaN
#
#    time_to_recover algorithm  simulation
# 0              NaN   MuSFiCO          17
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              0.0             0.0           NaN                  NaN
#
#    time_to_recover algorithm  simulation
# 0              NaN   MuSFiCO          18
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              0.0             0.0           NaN                  NaN
#
#    time_to_recover algorithm  simulation
# 0              NaN   MuSFiCO          19
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              0.0             0.0           NaN                  NaN
#
#    time_to_recover algorithm  simulation
# 0              NaN   MuSFiCO          20
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              0.0             0.0           NaN                  NaN
#
#    time_to_recover algorithm  simulation
# 0              NaN   MuSFiCO          21
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              0.0             0.0           NaN                  NaN
#
#    time_to_recover algorithm  simulation
# 0              NaN   MuSFiCO          22
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0         0.133333             0.0           0.0                 50.0
#
#    time_to_recover algorithm  simulation
# 0        30.898009   MuSFiCO          23
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              0.0             0.0           NaN                  NaN
#
#    time_to_recover algorithm  simulation
# 0              NaN   MuSFiCO          24
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              0.0             0.0           NaN                  NaN
#
#    time_to_recover algorithm  simulation
# 0              NaN   MuSFiCO          25
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              0.0             0.0           NaN                  NaN
#
#    time_to_recover algorithm  simulation
# 0              NaN   MuSFiCO          26
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              0.0             0.0           NaN                  NaN
#
#    time_to_recover algorithm  simulation
# 0              NaN   MuSFiCO          27
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              0.0             0.0           NaN                  NaN
#
#    time_to_recover algorithm  simulation
# 0              NaN   MuSFiCO          28
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0              0.0             0.0           NaN                  NaN
#
#    time_to_recover algorithm  simulation
# 0              NaN   MuSFiCO          29
#    recover_success  backup_success  latency_diff  latency_improvement  \
# 0         0.172414             0.0           0.0                 50.0
#
#    time_to_recover algorithm  simulation
# 0        30.693337   MuSFiCO          30
#
# Resumo das Simulações:
# Algoritmo: GA
#   Quantidade de arquivos: 40
#   Simulações de sucesso: 30
#   Dados nulos: 0
#
# Algoritmo: Greedy
#   Quantidade de arquivos: 40
#   Simulações de sucesso: 30
#   Dados nulos: 0
#
# Algoritmo: MSF
#   Quantidade de arquivos: 40
#   Simulações de sucesso: 30
#   Dados nulos: 0
#
# Algoritmo: MuSFiCO
#   Quantidade de arquivos: 41
#   Simulações de sucesso: 31
#   Dados nulos: 87

# %%
aggregated_simulation_data
# Out:
#     recover_success  backup_success  latency_diff  latency_improvement  \
# 0          1.000000             0.0     -0.142857            51.428571
# 0          1.000000             0.0      0.533333            44.666667
# 0          0.857143             0.0      0.055556            49.444444
# 0          0.875000             0.0      0.142857            48.571429
# 0          0.863636             0.0     -0.052632            50.526316
# ..              ...             ...           ...                  ...
# 0          0.000000             0.0           NaN                  NaN
# 0          0.000000             0.0           NaN                  NaN
# 0          0.000000             0.0           NaN                  NaN
# 0          0.000000             0.0           NaN                  NaN
# 0          0.172414             0.0      0.000000            50.000000
#
#     time_to_recover algorithm  simulation
# 0         15.653104        GA           0
# 0         18.344961        GA           1
# 0         17.795003        GA           2
# 0         22.161413        GA           3
# 0         29.219553        GA           4
# ..              ...       ...         ...
# 0               NaN   MuSFiCO          26
# 0               NaN   MuSFiCO          27
# 0               NaN   MuSFiCO          28
# 0               NaN   MuSFiCO          29
# 0         30.693337   MuSFiCO          30
#
# [121 rows x 7 columns]

# %% [markdown]
# # Gráfico 1 <a id="gr1"></a>

# %% [markdown]
# taxa de sucesso na realocação. Usuários afetados que foram realocados devidamente dividido pelo total de usuários afetados

# %%
! pip install kaleido
# Out:
# Requirement already satisfied: kaleido in c:\users\rodri\anaconda3\envs\mu-sfc\lib\site-packages (0.2.1)

# %%
import plotly.graph_objects as go


df = aggregated_simulation_data


# Lista de métricas
metrics = [
    "recover_success",
    "backup_success",
    "latency_diff",
    "latency_improvement",
    "time_to_recover",
]


# Criação de um gráfico para cada métrica
for metric in metrics:
    fig = go.Figure()
    for algo in df["algorithm"].unique():
        algo_data = df[df["algorithm"] == algo]
        fig.add_trace(
            go.Box(
                y=algo_data[metric], name=algo, boxmean=True, marker=dict(size=6), showlegend=True
            )
        )

    fig.update_layout(
        yaxis_title=metric,
        xaxis_title="Algorithm",
        boxmode="group",
        legend=dict(
            orientation="h",  # Legenda na horizontal
            yanchor="bottom",
            y=1.05,  # Coloca a legenda logo acima do gráfico
            xanchor="center",
            x=0.5,
            font=dict(size=14),  # Aumenta o tamanho da fonte da legenda
        ),
        autosize=True,  # Permite o ajuste automático do tamanho
        margin=dict(l=50, r=50, t=10, b=50),  # Ajustes nas margens para mais flexibilidade
        height=400,  # Ajuste flexível no tamanho do plot
        width=600,  # Ajuste flexível no tamanho do plot
        font=dict(
            size=16  # Aumenta o tamanho geral da fonte
        ),
    )

    # Ajusta o tamanho da fonte dos eixos
    fig.update_xaxes(title_font=dict(size=18), tickfont=dict(size=14))
    fig.update_yaxes(title_font=dict(size=18), tickfont=dict(size=14))
    # Nome do arquivo baseado na métrica
    file_name = f"{metric}.pdf"
    fig.write_image(file_name, format="pdf")
    fig.show()
